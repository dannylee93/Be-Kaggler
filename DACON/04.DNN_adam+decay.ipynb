# %% [markdown]
# <br>
#
# ## 데이터 전처리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 불러오기
train_origin = pd.read_csv('train.csv', index_col=0)
train = pd.read_csv('train_x_0.2_99.8.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)

# Train 데이터의 타입을 Sample_submission에 대응하는 가변수 형태로 변환
column_number = {}
for i, column in enumerate(sample_submission.columns):
    column_number[column] = i
    
def to_number(x, dic):
    return dic[x]

train_origin['type_num'] = train_origin['type'].apply(lambda x : to_number(x, column_number))

# 모델에 적용할 데이터 셋 준비 
x = train
y = train_origin['type_num']

x = x.drop(columns=['fiberID'], axis=1)
test_x = test.drop(columns=['fiberID'],axis=1)

col_name = x.columns

x = np.array(x)
x = x.astype('float32')

y = np.array(y)

test_x = np.array(test_x)
test_x = test_x.astype('float32')

from sklearn.model_selection import train_test_split, KFold
x_train, x_test, y_train, y_test = train_test_split(x,y, 
                                                    train_size=0.7, 
                                                    shuffle=True ,
                                                    random_state=0)

from sklearn.preprocessing import StandardScaler

scaler2 = StandardScaler()

scaler2.fit(x_train)
x_train = scaler2.transform(x_train)
x_test = scaler2.transform(x_test)

test_x = scaler2.transform(test_x)

from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# C:\Users\student\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# Using TensorFlow backend.

# %% [markdown]
# <br>
#
# ## 모델링

# %%
# 모델링
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.regularizers import l2
from keras.initializers import he_normal
from keras.optimizers import adam

num_classes = 19

model=Sequential()

model.add(Dense(64,input_shape=(20, ))) # input dimension
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.1))

model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.1))
# model.add(Dense(128, kernel_initializer=, kernel_regularizer=l2(0.01), bias_regularizer= l2(0.01), bias_initializer=))
# model.add(LeakyReLU(alpha=0.1))
# model.add(Dropout(0.1))

model.add(Dense(256))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.1))

model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.1))

model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.4))

model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                1344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 19)                2451
# =================================================================
# Total params: 94,547
# Trainable params: 94,547
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Optimizer의 파라미터 변경
optimizer_adam = adam(lr=0.001, clipvalue=1.0, decay=1e-8/50)

# 모델 훈련
model.compile(loss='categorical_crossentropy', optimizer= optimizer_adam, metrics=['accuracy'])

hist = model.fit(x_train, y_train, batch_size=38, epochs=50, verbose=2,validation_split=0.25)
loss, acc = model.evaluate(x_test,y_test,batch_size=64)
print('Loss:',loss,'Accuracy:',acc)
# Out:
# Train on 104994 samples, validate on 34999 samples
# Epoch 1/50
#  - 7s - loss: 0.7172 - accuracy: 0.7724 - val_loss: 0.5099 - val_accuracy: 0.8287
# Epoch 2/50
#  - 7s - loss: 0.5521 - accuracy: 0.8193 - val_loss: 0.4686 - val_accuracy: 0.8387
# Epoch 3/50
#  - 7s - loss: 0.5239 - accuracy: 0.8259 - val_loss: 0.4501 - val_accuracy: 0.8456
# Epoch 4/50
#  - 7s - loss: 0.5074 - accuracy: 0.8301 - val_loss: 0.4530 - val_accuracy: 0.8454
# Epoch 5/50
#  - 7s - loss: 0.4993 - accuracy: 0.8328 - val_loss: 0.4477 - val_accuracy: 0.8459
# Epoch 6/50
#  - 7s - loss: 0.4907 - accuracy: 0.8350 - val_loss: 0.4382 - val_accuracy: 0.8518
# Epoch 7/50
#  - 7s - loss: 0.4865 - accuracy: 0.8368 - val_loss: 0.4360 - val_accuracy: 0.8523
# Epoch 8/50
#  - 7s - loss: 0.4814 - accuracy: 0.8386 - val_loss: 0.4397 - val_accuracy: 0.8489
# Epoch 9/50
#  - 7s - loss: 0.4755 - accuracy: 0.8397 - val_loss: 0.4561 - val_accuracy: 0.8461
# Epoch 10/50
#  - 7s - loss: 0.4742 - accuracy: 0.8406 - val_loss: 0.4356 - val_accuracy: 0.8495
# Epoch 11/50
#  - 7s - loss: 0.4722 - accuracy: 0.8411 - val_loss: 0.4212 - val_accuracy: 0.8539
# Epoch 12/50
#  - 7s - loss: 0.4677 - accuracy: 0.8429 - val_loss: 0.4211 - val_accuracy: 0.8547
# Epoch 13/50
#  - 7s - loss: 0.4672 - accuracy: 0.8428 - val_loss: 0.4303 - val_accuracy: 0.8514
# Epoch 14/50
#  - 7s - loss: 0.4657 - accuracy: 0.8437 - val_loss: 0.4208 - val_accuracy: 0.8562
# Epoch 15/50
#  - 7s - loss: 0.4623 - accuracy: 0.8443 - val_loss: 0.4252 - val_accuracy: 0.8537
# Epoch 16/50
#  - 7s - loss: 0.4632 - accuracy: 0.8426 - val_loss: 0.4294 - val_accuracy: 0.8538
# Epoch 17/50
#  - 7s - loss: 0.4591 - accuracy: 0.8446 - val_loss: 0.4138 - val_accuracy: 0.8585
# Epoch 18/50
#  - 7s - loss: 0.4602 - accuracy: 0.8456 - val_loss: 0.4209 - val_accuracy: 0.8542
# Epoch 19/50
#  - 7s - loss: 0.4584 - accuracy: 0.8461 - val_loss: 0.4212 - val_accuracy: 0.8563
# Epoch 20/50
#  - 7s - loss: 0.4560 - accuracy: 0.8463 - val_loss: 0.4138 - val_accuracy: 0.8579
# Epoch 21/50
#  - 7s - loss: 0.4550 - accuracy: 0.8452 - val_loss: 0.4256 - val_accuracy: 0.8562
# Epoch 22/50
#  - 7s - loss: 0.4560 - accuracy: 0.8460 - val_loss: 0.4197 - val_accuracy: 0.8537
# Epoch 23/50
#  - 7s - loss: 0.4532 - accuracy: 0.8469 - val_loss: 0.4200 - val_accuracy: 0.8538
# Epoch 24/50
#  - 7s - loss: 0.4520 - accuracy: 0.8469 - val_loss: 0.4216 - val_accuracy: 0.8548
# Epoch 25/50
#  - 7s - loss: 0.4529 - accuracy: 0.8475 - val_loss: 0.4177 - val_accuracy: 0.8545
# Epoch 26/50
#  - 7s - loss: 0.4527 - accuracy: 0.8472 - val_loss: 0.4186 - val_accuracy: 0.8523
# Epoch 27/50
#  - 7s - loss: 0.4514 - accuracy: 0.8477 - val_loss: 0.4057 - val_accuracy: 0.8602
# Epoch 28/50
#  - 7s - loss: 0.4506 - accuracy: 0.8477 - val_loss: 0.4218 - val_accuracy: 0.8551
# Epoch 29/50
#  - 7s - loss: 0.4522 - accuracy: 0.8472 - val_loss: 0.4324 - val_accuracy: 0.8535
# Epoch 30/50
#  - 7s - loss: 0.4483 - accuracy: 0.8477 - val_loss: 0.4211 - val_accuracy: 0.8538
# Epoch 31/50
#  - 7s - loss: 0.4490 - accuracy: 0.8472 - val_loss: 0.4121 - val_accuracy: 0.8583
# Epoch 32/50
#  - 8s - loss: 0.4478 - accuracy: 0.8477 - val_loss: 0.4145 - val_accuracy: 0.8592
# Epoch 33/50
#  - 8s - loss: 0.4487 - accuracy: 0.8483 - val_loss: 0.4221 - val_accuracy: 0.8536
# Epoch 34/50
#  - 7s - loss: 0.4452 - accuracy: 0.8501 - val_loss: 0.4114 - val_accuracy: 0.8587
# Epoch 35/50
#  - 7s - loss: 0.4436 - accuracy: 0.8495 - val_loss: 0.4085 - val_accuracy: 0.8578
# Epoch 36/50
#  - 7s - loss: 0.4448 - accuracy: 0.8490 - val_loss: 0.4086 - val_accuracy: 0.8588
# Epoch 37/50
#  - 7s - loss: 0.4480 - accuracy: 0.8498 - val_loss: 0.4184 - val_accuracy: 0.8574
# Epoch 38/50
#  - 7s - loss: 0.4406 - accuracy: 0.8512 - val_loss: 0.4065 - val_accuracy: 0.8618
# Epoch 39/50
#  - 7s - loss: 0.4447 - accuracy: 0.8499 - val_loss: 0.4265 - val_accuracy: 0.8501
# Epoch 40/50
#  - 7s - loss: 0.4447 - accuracy: 0.8494 - val_loss: 0.4098 - val_accuracy: 0.8600
# Epoch 41/50
#  - 7s - loss: 0.4426 - accuracy: 0.8504 - val_loss: 0.4122 - val_accuracy: 0.8566
# Epoch 42/50
#  - 7s - loss: 0.4418 - accuracy: 0.8500 - val_loss: 0.4089 - val_accuracy: 0.8599
# Epoch 43/50
#  - 8s - loss: 0.4432 - accuracy: 0.8492 - val_loss: 0.4144 - val_accuracy: 0.8536
# Epoch 44/50
#  - 8s - loss: 0.4436 - accuracy: 0.8504 - val_loss: 0.4119 - val_accuracy: 0.8581
# Epoch 45/50
#  - 8s - loss: 0.4417 - accuracy: 0.8507 - val_loss: 0.4107 - val_accuracy: 0.8590
# Epoch 46/50
#  - 8s - loss: 0.4428 - accuracy: 0.8499 - val_loss: 0.4112 - val_accuracy: 0.8585
# Epoch 47/50
#  - 8s - loss: 0.4413 - accuracy: 0.8508 - val_loss: 0.4125 - val_accuracy: 0.8595
# Epoch 48/50
#  - 8s - loss: 0.4424 - accuracy: 0.8499 - val_loss: 0.4081 - val_accuracy: 0.8582
# Epoch 49/50
#  - 8s - loss: 0.4420 - accuracy: 0.8505 - val_loss: 0.4199 - val_accuracy: 0.8534
# Epoch 50/50
#  - 8s - loss: 0.4379 - accuracy: 0.8507 - val_loss: 0.4009 - val_accuracy: 0.8606
# 59998/59998 [==============================] - 1s 16us/step
# Loss: 0.40351772634894606 Accuracy: 0.8609787225723267

# %%
# 학습결과 시각화 

import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
plt.plot(hist.history["loss"], label="train_loss")
plt.plot(hist.history["val_loss"], label="val_loss")
plt.plot(hist.history["accuracy"], label="accuracy")
plt.plot(hist.history["val_accuracy"], label="val_accuracy")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
