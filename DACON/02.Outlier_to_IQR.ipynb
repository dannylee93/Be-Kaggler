# %% [markdown]
# <br>
#
# ## Original Train data

# %%
# 패키지 임포트
import pandas as pd

# 데이터 불러오기
train = pd.read_csv('train.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_x = np.array(train)

# 그래프 그리기
plt.figure(figsize=(15,15))
for i in range(0,20):
    plt.subplot(4,5,i+1)
    plt.hist(train_x[:,i],bins=50)
    plt.gca().set_title(train.columns[i])

# %% [markdown]
# <br>
#
# ## 25~75% 값으로 변경

# %%
# 패키지 임포트
import pandas as pd

# 데이터 불러오기
train = pd.read_csv('train_x_2575.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_x = np.array(train)

# 그래프 그리기
plt.figure(figsize=(15,15))
for i in range(0,20):
    plt.subplot(4,5,i+1)
    plt.hist(train_x[:,i],bins=50)
    plt.gca().set_title(train.columns[i])

# %% [markdown]
# <br>
#
# ## 5~95% 값으로 변경

# %%
# 패키지 임포트
import pandas as pd

# 데이터 불러오기
train = pd.read_csv('train_x_595.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_x = np.array(train)

# 그래프 그리기
plt.figure(figsize=(15,15))
for i in range(0,20):
    plt.subplot(4,5,i+1)
    plt.hist(train_x[:,i],bins=50)
    plt.gca().set_title(train.columns[i])

# %% [markdown]
# <br>
#
# ## 2~98% 값으로 변경

# %%
# 패키지 임포트
import pandas as pd

# 데이터 불러오기
train = pd.read_csv('train_x_298.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_x = np.array(train)

# 그래프 그리기
plt.figure(figsize=(15,15))
for i in range(0,20):
    plt.subplot(4,5,i+1)
    plt.hist(train_x[:,i],bins=50)
    plt.gca().set_title(train.columns[i])

# %% [markdown]
# <br>
#
# ## 1~99% 값으로 변경

# %%
# 패키지 임포트
import pandas as pd


# 데이터 불러오기
train = pd.read_csv('train_x_199.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_x = np.array(train)

# 그래프 그리기
plt.figure(figsize=(15,15))
for i in range(0,20):
    plt.subplot(4,5,i+1)
    plt.hist(train_x[:,i],bins=50)
    plt.gca().set_title(train.columns[i])

# %% [markdown]
# <br>
#
# ## 0.5~99.5% 값으로 변경

# %%
# 패키지 임포트
import pandas as pd

# 데이터 불러오기
train = pd.read_csv('train_x_0.5_99.5.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_x = np.array(train)

# 그래프 그리기
plt.figure(figsize=(15,15))
for i in range(0,20):
    plt.subplot(4,5,i+1)
    plt.hist(train_x[:,i],bins=50)
    plt.gca().set_title(train.columns[i])

# %%
# 패키지 임포트
import pandas as pd

# 데이터 불러오기
train = pd.read_csv('train_x_0.5_99.5.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)

import numpy as np
import matplotlib.pyplot as plt

# Prescaling
from sklearn import preprocessing

train_x = np.array(train)
scaler = preprocessing.RobustScaler()
scaler.fit(train_x)
train_x = scaler.transform(train_x)

# 그래프 그리기
plt.figure(figsize=(15,15))
for i in range(0,20):
    plt.subplot(4,5,i+1)
    plt.hist(train_x[:,i],bins=50)
    plt.gca().set_title(train.columns[i])

# %% [markdown]
# <br>
#
# ## 0.2~99.8% 값으로 변경

# %%
# 패키지 임포트
import pandas as pd

# 데이터 불러오기
train = pd.read_csv('train_x_0.2_99.8.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_x = np.array(train)

# 그래프 그리기
plt.figure(figsize=(15,15))
for i in range(0,20):
    plt.subplot(4,5,i+1)
    plt.hist(train_x[:,i],bins=50)
    plt.gca().set_title(train.columns[i])
