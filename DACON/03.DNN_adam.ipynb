# %% [markdown]
# <br>
#
# ## 데이터 전처리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 불러오기
train_origin = pd.read_csv('train.csv', index_col=0)
train = pd.read_csv('train_x_0.2_99.8.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)

# Train 데이터의 타입을 Sample_submission에 대응하는 가변수 형태로 변환
column_number = {}
for i, column in enumerate(sample_submission.columns):
    column_number[column] = i
    
def to_number(x, dic):
    return dic[x]

train_origin['type_num'] = train_origin['type'].apply(lambda x : to_number(x, column_number))

# 모델에 적용할 데이터 셋 준비 
x = train
y = train_origin['type_num']

x = x.drop(columns=['fiberID'], axis=1)
test_x = test.drop(columns=['fiberID'],axis=1)

col_name = x.columns

x = np.array(x)
x = x.astype('float32')

y = np.array(y)

test_x = np.array(test_x)
test_x = test_x.astype('float32')

from sklearn.model_selection import train_test_split, KFold
x_train, x_test, y_train, y_test = train_test_split(x,y, 
                                                    train_size=0.7, 
                                                    shuffle=True ,
                                                    random_state=0)

from sklearn.preprocessing import StandardScaler

scaler2 = StandardScaler()

scaler2.fit(x_train)
x_train = scaler2.transform(x_train)
x_test = scaler2.transform(x_test)

test_x = scaler2.transform(test_x)

from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# C:\Users\student\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# Using TensorFlow backend.

# %% [markdown]
# <br>
#
# ## DNN 모델링

# %%
# 모델링
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.regularizers import l2
from keras.initializers import he_normal
from keras.optimizers import adam

num_classes = 19

model=Sequential()

model.add(Dense(64,input_shape=(20, ))) # input dimension
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.1))

model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.1))
# model.add(Dense(128, kernel_initializer=, kernel_regularizer=l2(0.01), bias_regularizer= l2(0.01), bias_initializer=))
# model.add(LeakyReLU(alpha=0.1))
# model.add(Dropout(0.1))

model.add(Dense(256))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.1))

model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.1))

model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.4))

model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                1344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 19)                2451
# =================================================================
# Total params: 94,547
# Trainable params: 94,547
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 훈련
model.compile(loss='categorical_crossentropy', optimizer= 'adam', metrics=['accuracy'])

hist = model.fit(x_train, y_train, batch_size=38, epochs=50, verbose=2,validation_split=0.25)
loss, acc = model.evaluate(x_test,y_test,batch_size=64)
print('Loss:',loss,'Accuracy:',acc)
# Out:
# Train on 104994 samples, validate on 34999 samples
# Epoch 1/50
#  - 7s - loss: 0.7162 - accuracy: 0.7739 - val_loss: 0.5278 - val_accuracy: 0.8211
# Epoch 2/50
#  - 7s - loss: 0.5479 - accuracy: 0.8203 - val_loss: 0.5074 - val_accuracy: 0.8355
# Epoch 3/50
#  - 7s - loss: 0.5238 - accuracy: 0.8257 - val_loss: 0.4667 - val_accuracy: 0.8392
# Epoch 4/50
#  - 7s - loss: 0.5070 - accuracy: 0.8310 - val_loss: 0.4544 - val_accuracy: 0.8419
# Epoch 5/50
#  - 7s - loss: 0.4974 - accuracy: 0.8333 - val_loss: 0.4534 - val_accuracy: 0.8461
# Epoch 6/50
#  - 7s - loss: 0.4907 - accuracy: 0.8351 - val_loss: 0.4342 - val_accuracy: 0.8514
# Epoch 7/50
#  - 7s - loss: 0.4836 - accuracy: 0.8387 - val_loss: 0.4360 - val_accuracy: 0.8507
# Epoch 8/50
#  - 7s - loss: 0.4801 - accuracy: 0.8381 - val_loss: 0.4353 - val_accuracy: 0.8472
# Epoch 9/50
#  - 7s - loss: 0.4757 - accuracy: 0.8402 - val_loss: 0.4324 - val_accuracy: 0.8503
# Epoch 10/50
#  - 7s - loss: 0.4741 - accuracy: 0.8408 - val_loss: 0.4464 - val_accuracy: 0.8443
# Epoch 11/50
#  - 7s - loss: 0.4685 - accuracy: 0.8415 - val_loss: 0.4545 - val_accuracy: 0.8423
# Epoch 12/50
#  - 7s - loss: 0.4710 - accuracy: 0.8408 - val_loss: 0.4324 - val_accuracy: 0.8500
# Epoch 13/50
#  - 7s - loss: 0.4674 - accuracy: 0.8427 - val_loss: 0.4362 - val_accuracy: 0.8506
# Epoch 14/50
#  - 7s - loss: 0.4656 - accuracy: 0.8433 - val_loss: 0.4213 - val_accuracy: 0.8544
# Epoch 15/50
#  - 7s - loss: 0.4608 - accuracy: 0.8429 - val_loss: 0.4180 - val_accuracy: 0.8539
# Epoch 16/50
#  - 7s - loss: 0.4600 - accuracy: 0.8446 - val_loss: 0.4223 - val_accuracy: 0.8554
# Epoch 17/50
#  - 7s - loss: 0.4582 - accuracy: 0.8451 - val_loss: 0.4543 - val_accuracy: 0.8422
# Epoch 18/50
#  - 7s - loss: 0.4590 - accuracy: 0.8442 - val_loss: 0.4213 - val_accuracy: 0.8557
# Epoch 19/50
#  - 7s - loss: 0.4566 - accuracy: 0.8453 - val_loss: 0.4188 - val_accuracy: 0.8562
# Epoch 20/50
#  - 7s - loss: 0.4551 - accuracy: 0.8466 - val_loss: 0.4140 - val_accuracy: 0.8580
# Epoch 21/50
#  - 7s - loss: 0.4557 - accuracy: 0.8461 - val_loss: 0.4165 - val_accuracy: 0.8544
# Epoch 22/50
#  - 7s - loss: 0.4536 - accuracy: 0.8470 - val_loss: 0.4209 - val_accuracy: 0.8530
# Epoch 23/50
#  - 7s - loss: 0.4555 - accuracy: 0.8451 - val_loss: 0.4067 - val_accuracy: 0.8599
# Epoch 24/50
#  - 7s - loss: 0.4516 - accuracy: 0.8476 - val_loss: 0.4099 - val_accuracy: 0.8563
# Epoch 25/50
#  - 7s - loss: 0.4529 - accuracy: 0.8465 - val_loss: 0.4132 - val_accuracy: 0.8571
# Epoch 26/50
#  - 7s - loss: 0.4527 - accuracy: 0.8478 - val_loss: 0.4177 - val_accuracy: 0.8540
# Epoch 27/50
#  - 7s - loss: 0.4508 - accuracy: 0.8478 - val_loss: 0.4146 - val_accuracy: 0.8566
# Epoch 28/50
#  - 7s - loss: 0.4492 - accuracy: 0.8473 - val_loss: 0.4195 - val_accuracy: 0.8538
# Epoch 29/50
#  - 7s - loss: 0.4506 - accuracy: 0.8470 - val_loss: 0.4082 - val_accuracy: 0.8586
# Epoch 30/50
#  - 7s - loss: 0.4474 - accuracy: 0.8467 - val_loss: 0.4146 - val_accuracy: 0.8560
# Epoch 31/50
#  - 7s - loss: 0.4473 - accuracy: 0.8477 - val_loss: 0.4414 - val_accuracy: 0.8559
# Epoch 32/50
#  - 7s - loss: 0.4479 - accuracy: 0.8483 - val_loss: 0.4240 - val_accuracy: 0.8553
# Epoch 33/50
#  - 7s - loss: 0.4454 - accuracy: 0.8484 - val_loss: 0.4177 - val_accuracy: 0.8553
# Epoch 34/50
#  - 7s - loss: 0.4458 - accuracy: 0.8491 - val_loss: 0.4079 - val_accuracy: 0.8588
# Epoch 35/50
#  - 7s - loss: 0.4451 - accuracy: 0.8492 - val_loss: 0.4092 - val_accuracy: 0.8592
# Epoch 36/50
#  - 7s - loss: 0.4422 - accuracy: 0.8502 - val_loss: 0.4116 - val_accuracy: 0.8563
# Epoch 37/50
#  - 7s - loss: 0.4451 - accuracy: 0.8487 - val_loss: 0.4078 - val_accuracy: 0.8613
# Epoch 38/50
#  - 7s - loss: 0.4435 - accuracy: 0.8493 - val_loss: 0.4032 - val_accuracy: 0.8596
# Epoch 39/50
#  - 7s - loss: 0.4435 - accuracy: 0.8489 - val_loss: 0.4126 - val_accuracy: 0.8553
# Epoch 40/50
#  - 7s - loss: 0.4440 - accuracy: 0.8484 - val_loss: 0.4301 - val_accuracy: 0.8490
# Epoch 41/50
#  - 7s - loss: 0.4430 - accuracy: 0.8502 - val_loss: 0.4115 - val_accuracy: 0.8596
# Epoch 42/50
#  - 7s - loss: 0.4422 - accuracy: 0.8503 - val_loss: 0.4089 - val_accuracy: 0.8572
# Epoch 43/50
#  - 7s - loss: 0.4415 - accuracy: 0.8509 - val_loss: 0.4140 - val_accuracy: 0.8548
# Epoch 44/50
#  - 7s - loss: 0.4428 - accuracy: 0.8503 - val_loss: 0.4071 - val_accuracy: 0.8619
# Epoch 45/50
#  - 7s - loss: 0.4413 - accuracy: 0.8502 - val_loss: 0.4041 - val_accuracy: 0.8607
# Epoch 46/50
#  - 7s - loss: 0.4415 - accuracy: 0.8502 - val_loss: 0.4025 - val_accuracy: 0.8593
# Epoch 47/50
#  - 7s - loss: 0.4432 - accuracy: 0.8506 - val_loss: 0.4178 - val_accuracy: 0.8541
# Epoch 48/50
#  - 7s - loss: 0.4409 - accuracy: 0.8507 - val_loss: 0.3987 - val_accuracy: 0.8615
# Epoch 49/50
#  - 7s - loss: 0.4412 - accuracy: 0.8493 - val_loss: 0.4032 - val_accuracy: 0.8588
# Epoch 50/50
#  - 7s - loss: 0.4389 - accuracy: 0.8512 - val_loss: 0.4143 - val_accuracy: 0.8593
# 59998/59998 [==============================] - 1s 14us/step
# Loss: 0.41800036225689585 Accuracy: 0.8600953221321106

# %%
# 학습결과 시각화

import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
plt.plot(hist.history["loss"], label="train_loss")
plt.plot(hist.history["val_loss"], label="val_loss")
plt.plot(hist.history["accuracy"], label="accuracy")
plt.plot(hist.history["val_accuracy"], label="val_accuracy")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
